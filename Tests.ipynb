# %%
from classes import *
import random

# %%
d = {'a': -2, 'b': 2, 'c': -1, 'd': 1, 'e': 0}

print("High to Low: ", sort_hl(d))
print("Low To High: ", sort_lh(d))

print('\n')

print("Abs High to Low: ", sort_abs_hl(d))
print("Abs Low To High: ", sort_abs_lh(d))

print('\n')

d = {'1': 'cat', '2': 'elephant', '3': 'hyena', '4': 'albatross', '5': 'humuhumunukunukuāpuaʻa'}

print("Len High to Low: ", sort_len_hl(d))
print("Len Low To High: ", sort_len_lh(d))

print('\n')

text = [
    ('My', 13),
    ('name', 14),
    ('is', 9),
    ('Bob', 2),
    ('\n', 0),
    ('and', 1),
    ('this', 20),
    ('is', 9),
    ('a', 1),
    ('rating', 18),
    ('of', 15),
    ('position', 16),
    ('\n', 0),
    ('of', 15),
    ('first', 6),
    ('letter', 12),
    ('in', 9),
    ('the', 20),
    ('alphabet', 1),
]

print_scanned_text(text)

d = {'cat owners': 5, 'dog owners': 2, 'lizard owners': 8, 'parrot owners': 6}

plot_size = .5

setup_plot(plot_size)
plot_dict(d, add_mode = 'additive')
setup_plot(plot_size)
plot_dict(d, mode = 'line', add_mode = 'additive')
setup_plot(plot_size)
plot_dict(d, mode = 'pie', add_mode = 'additive')
setup_plot(plot_size)
plot_dict(d, mode = 'scatter', add_mode = 'additive')
# Out:
# High to Low:  {'b': 2, 'd': 1, 'e': 0, 'c': -1, 'a': -2}
# Low To High:  {'a': -2, 'c': -1, 'e': 0, 'd': 1, 'b': 2}
#
#
# Abs High to Low:  {'a': -2, 'b': 2, 'c': -1, 'd': 1, 'e': 0}
# Abs Low To High:  {'e': 0, 'c': -1, 'd': 1, 'a': -2, 'b': 2}
#
#
# Len High to Low:  {'5': 'humuhumunukunukuāpuaʻa', '4': 'albatross', '2': 'elephant', '3': 'hyena', '1': 'cat'}
# Len Low To High:  {'1': 'cat', '3': 'hyena', '2': 'elephant', '4': 'albatross', '5': 'humuhumunukunukuāpuaʻa'}
#
#
# My name is Bob
#  and this is a rating of position
#  of first letter in the alphabet

# %%
c1 = CRV({'the': .7, 'ate': .2, '.': .1})
c2 = CRV({'the': .4, 'ate': .5, '.': .1})\

c3 = (c1 + c2) / 2

print(c3)

print('\n')

c3.print_full()
# Out:
# { + 0.55⋅the + 0.35⋅ate + 0.1⋅.}
#
#
# + 0.55⋅the
# + 0.35⋅ate
# + 0.1⋅.

# %%
corpus = Corpus(
    # path to the json file
    filepath = 'corpora/recipes',
    # path to the spelling dictionary
    spell_correct = 'corpora/spelling_dictionary',
    # do not seperate (e.g., bringing => bring ing)
    lemmatize = False,
    # remove any words that appear only once; replace with <UNK> in the source text
    removal_threshold = 1)
# Out:
# Data collected:
#     - 4107 unique words found.
#     - most common words: ['\n', '-', '.', '1', ',']
#     - least common words: ['www', 'yet', 'zinfandel', 'zip', 'zipper']
#
#
# Corpus loaded:
#     - 5000 sentences.
#     - longest sentence:
#
# <START> whole wheat yeast bread
#
#  ingredients :
#  - 1 cup ( 2 2 5 ml ) scalded milk
#  - 1 / 4 cup ( 6 0 ml ) lard
#  - 4 tsp ( 2 0 ml ) . salt
#  - 1 / 4 cup ( 6 0 ml ) honey
#  - 1 cup ( 2 2 5 ml ) water , 1 1 0 - 1 1 5 degrees
#  - 2 pkg . dry yeast
#  - 2 tbsp ( 3 0 ml ) . brown sugar
#  - 2 cups ( 4 7 5 ml ) whole wheat flour
#  - 3 cups ( 7 0 0 ml ) or more white flour
#
#  directions :
#  - mix scalded milk , lard , salt & honey and let cool to lukewarm - about 8 5 degrees ( 3 0 c . ) .
#  - mix water , yeast & brown sugar and let stand to dissolve for 2 - 3 minutes .
#  - add yeast mixture to milk mixture .
#  - add whole wheat flour and enough white flour to make dough .
#  - mix well .
#  - knead 5 - 1 0 minutes .
#  - put in bowl to rise until double in size .
#  - punch down and divide into two portions .
#  - let rest 5 - 1 0 minutes and then shape into two loaves .
#  - let rise in pans one hour or until double in bulk .
#  - bake at 3 7 5 degrees ( 2 0 0 c . ) for 5 minutes and 3 5 0 degrees ( 1 7 5 c . ) for 3 0 - 3 5 minutes .
#  - remove from pans and let cool thoroughly before wrapping <END>
# .
#     - shortest sentence:
#
# <START> test
#
#  ingredients :
#  - 1 kg pork
#
#  directions :
#  - combine the first 3 ingredients <END>

# %%
corpus.find('kraft')
# Out:
# 1 clove garlic , minced
#  - 1 / 4 cup kraft balsamic vinaigrette dressing
#  - 1 lb .
#
#
#
#
#  - 1 ( 7 1 / 4 ounce ) package kraft macaroni and cheese
#  - 3 4 cup
#
#
#
# cups quartered yukon gold potatoes
#  - 3 / 4 cup kraft real mayo mayonnaise
#  - 1 tbsp .
#
#
#
#
#  ingredients :
#  - 4 - 1 / 2 cups kraft lime cilantro vinaigrette
#  - 1 cup cilantro
#
#
#
# - 1 cup salsa
#  - 4 1 0 g can kraft * braised steak & onions
#  - 3
#
#
#
# medium red onion , chopped
#  - 1 / 2 cup kraft lite catalina dressing
#  - 1 / 2
#
#
#
# 0 2 / 0 9
#  - 1 / 4 cup kraft asian sesame dressing , divided
#  - 1
#
#
#
# parmesan
#
#  ingredients :
#  - 1 / 3 cup kraft grated parmesan cheese
#  - 1 / 4
#
#
#
# / 2 cup pinch bread crumbs
#  - 2 tbsp . kraft grated parmesan cheese
#  - 2 tbsp .
#
#
#
# 4 cup classic tomato and basil pasta sauce
#  - 4 kraft provolone cheese slices
#  - 8 fresh basil
#
#
#
# Total Found : 267
# Found in 77 sentences
# {87,
#  227,
#  232,
#  271,
#  297,
#  380,
#  385,
#  421,
#  658,
#  811,
#  932,
#  934,
#  948,
#  1055,
#  1067,
#  1069,
#  1076,
#  1088,
#  1123,
#  1163,
#  1302,
#  1318,
#  1445,
#  1547,
#  1555,
#  1675,
#  1769,
#  1774,
#  1800,
#  1806,
#  1841,
#  1901,
#  1938,
#  2084,
#  2097,
#  2102,
#  2207,
#  2245,
#  2298,
#  2392,
#  2555,
#  2607,
#  2609,
#  2635,
#  2655,
#  2666,
#  2791,
#  2834,
#  2903,
#  3236,
#  3441,
#  3736,
#  3780,
#  3887,
#  3894,
#  4006,
#  4058,
#  4096,
#  4137,
#  4201,
#  4241,
#  4274,
#  4315,
#  4432,
#  4437,
#  4456,
#  4488,
#  4501,
#  4642,
#  4701,
#  4729,
#  4765,
#  4774,
#  4781,
#  4870,
#  4936,
#  4964}

# %%
print(random.choice(corpus.vocab))
# Out:
# steak

# %%
print(concat_sentence(random.choice(corpus.sentences)))
# Out:
# <START> zucchini bread
#
#  ingredients :
#  - 1 1 / 2 c . sugar
#  - 1 c . oil
#  - 3 eggs
#  - 2 c . zucchini , grated
#  - 1 tsp . vanilla
#  - 3 c . flour
#  - 1 tbsp . cinnamon
#  - 1 tsp . salt
#  - 1 tbsp . baking powder
#  - 1 c . nuts ( optional )
#
#  directions :
#  - preheat oven to 3 5 0 ° .
#  - mix dry ingredients together ( sugar , flour , salt , baking powder , baking soda and cinnamon ) .
#  - beat eggs with fork .
#  - add vanilla and mix together with grated zucchini . add zucchini mixture to dry ingredients , alternating with oil . blend in nuts ( optional ) .
#  - lightly grease and flour two bread pans .
#  - bake for 1 hour .
#  - yields 2 loaves . <END>

# %%
# remove any words that appear 2 or less times from the CRV encodings (not keys), as the vectorizer
# uses a large matrix for efficiency, instead of dicts, which are more compact
vectorizer = corpus.create_vectorizer(removal_threshold = 2)
# Out:
# Vectorizer created:
#     - 4107 unique words;
#     - 3369 CRV words

# %%
# print the CRV encoding of 'half'
print(vectorizer.to_CRV('half'))
# show words similar to 'half'; the word 'half' itself can be ignored.
plot_dict(vectorizer.rate_words('half'))
# Out:
# { + 0.09⋅and + 0.09⋅- + 0.06⋅in + 0.06⋅\n + 0.05⋅of + 0.05⋅the + 0.05⋅. + 0.04⋅half + 0.02⋅, + 0.02⋅cut + 0.01⋅with + 0.01⋅lengthwise + 0.01⋅a + 0.01⋅each + 0.01⋅add + 0.01⋅cup + 0.01⋅place + 0.01⋅& + 0.01⋅( + 0.01⋅; + 329 others}

# %%
# seems 'half' appears next to itself often... how so?
corpus.find(('half', 'half'))
# ahh... makes sense now!
# Out:
# - 2 tbsp . flour
#  - 1 c . half and half
#  - 1 tbsp . amaretto
#
#
#
#
# - 5 eggs
#  - 1 c . milk or half and half
#  - 1 c . broccoli florets
#
#
#
# - sprinkle with cheese . whisk eggs with milk or half and half and pour over mixture .
#  -
#
#
#
# chopped onions
#  - 1 / 2 c . sour half and half
#  - 1 / 4 c .
#
#
#
# and pepper ; mix well .
#  - add sour half and half .
#  - spread into an 8
#
#
#
#
#  - 1 quart orange juice
#  - 1 pint half & half
#  - . 5 pint whipping cream
#
#
#
# 4 . combine gin , lemonade , orange juice and half & half with the whipped items in a large
#
#
#
# / 4 c . sugar
#  - 3 c . half and half cream
#  - 1 tsp . vanilla
#
#
#
#
#  - and
#  - 1 1 / 2 cups half and half in a small saucepan .
#  -
#
#
#
# / 2 c . sugar
#  - 2 c . half and half
#  - 1 c . heavy whipping
#
#
#
# Total Found : 49
# Found in 35 sentences
# {79,
#  108,
#  111,
#  493,
#  676,
#  719,
#  916,
#  977,
#  1345,
#  1413,
#  1543,
#  1548,
#  1935,
#  1981,
#  2018,
#  2179,
#  2418,
#  2444,
#  2530,
#  2686,
#  3011,
#  3214,
#  3348,
#  3374,
#  3445,
#  3593,
#  3643,
#  3737,
#  3739,
#  3741,
#  3795,
#  3861,
#  3997,
#  4386,
#  4393}

# %%
print(vectorizer.to_CRV('diamond'))
plot_dict(vectorizer.rate_words('diamond'))
# Out:
# { + 0.12⋅, + 0.12⋅. + 0.12⋅1 + 0.12⋅cover + 0.12⋅each + 0.12⋅into + 0.12⋅making + 0.12⋅shapes}

# %%
plot_dict(vectorizer.rate_words(random.choice(corpus.vocab)))

# %%
db = CRVDatabase(filepath='saved_db.crvdb')

# %%
plot_dict(db.compare('cheddar'))
